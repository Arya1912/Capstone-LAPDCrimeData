# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
import pandas as pd
from src.feature_engineering import create_time_series_sequences, scale_sequences

# %%
# Load the K2 Experiment
df_k2 = pd.read_csv('../data/Crime_Data_K2.csv')
X2, y2, _ = create_time_series_sequences(df_k2)
X2_scaled, y2_scaled, _, _ = scale_sequences(X2, y2)

# Load the K4 Experiment
df_k4 = pd.read_csv('../data/Crime_Data_K4.csv')
X4, y4, _ = create_time_series_sequences(df_k4)
X4_scaled, y4_scaled, _, _ = scale_sequences(X4, y4)

print(f"K=2 Experiment: {X2_scaled.shape} sequences ready.")
print(f"K=4 Experiment: {X4_scaled.shape} sequences ready.")
# Out:
# K=2 Experiment: (1865, 14, 2) sequences ready.
# K=4 Experiment: (1865, 14, 4) sequences ready.
